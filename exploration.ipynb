# %%
import os
import osmnx as ox
import geopandas as gpd
import networkx as nx

# %%
G = ox.graph_from_place("Mexico", network_type="drive", simplify=False)
ox.plot_graph(G)
# Out:
# c:\Users\rabah\anaconda3\envs\appstreamlit\Lib\site-packages\osmnx\_overpass.py:271: UserWarning: This area is 1,723 times your configured Overpass max query area size. It will automatically be divided up into multiple sub-queries accordingly. This may take a long time.
#   multi_poly_proj = utils_geo._consolidate_subdivide_geometry(poly_proj)
